# %%
import pandas as pd

df = pd.read_excel('/content/hospitals_catalunya.xlsx', dtype={'Codi Postal': object})
df.head(3)
# Out:
#       Regió Sanitària  ...                             Horari
# 0  Alt Pirineu i Aran  ...  Urgències i emergències 24 hores.
# 1  Alt Pirineu i Aran  ...  Urgències i emergències 24 hores.
# 2  Alt Pirineu i Aran  ...  Urgències i emergències 24 hores.
#
# [3 rows x 10 columns]

# %%
df['input'] = df['Hospital'] + ", " + str(df['Codi Postal']) +  ", " + df['Municipi'] + ", Spain"
df.head(3)
# Out:
#       Regió Sanitària  ...                                              input
# 0  Alt Pirineu i Aran  ...  Fundació Sant Hospital, 0     25700\n1     175...
# 1  Alt Pirineu i Aran  ...  AECT Hospital de Cerdanya, 0     25700\n1     ...
# 2  Alt Pirineu i Aran  ...  Hospital Comarcal del Pallars, 0     25700\n1 ...
#
# [3 rows x 11 columns]

# %%
from geopy.geocoders import GoogleV3
geolocator = GoogleV3(api_key="AIzaSyDEzRfH6vsA5diDYg0EKXxnZ9Txb2mzg0s")

# %%
for index, row in df.iterrows():
  try: 
    address, (lat, lng) = geolocator.geocode(row['input'])
    df.loc[index, "address"] = address
    df.loc[index, "lat"] = lat
    df.loc[index, "lng"] = lng
  except:
    print(index, row['input'])
df

# %%
df.to_csv('hospitals_catalunya_geocoded.csv', index=False)
